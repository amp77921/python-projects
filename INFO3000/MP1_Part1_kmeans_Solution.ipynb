# %%
import numpy as np
#import cv2
#from PIL import Image
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from skimage import io

# %%
# Load image
img = io.imread('car.jpg')
print(img.shape)

# Display the original image
plt.figure(figsize=(6,6))
plt.imshow(img)
plt.title("Original Image")
plt.show()
# Out:
# (168, 300, 3)

# %%
# Normalize image
img = img / 255.0  # Normalize pixel values

# Reshape the image to be a list of RGB pixels
pixels = img.reshape(-1, 3)

# Fit KMeans on the pixel data
kmeans = KMeans(n_clusters=2).fit(pixels)

# Replace each pixel with its centroid
segmented_img = kmeans.cluster_centers_[kmeans.labels_]
segmented_img = segmented_img.reshape(img.shape)
# Out:
# /Users/jagannathrao/miniconda3/envs/ml/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Display the segmented image
plt.figure(figsize=(6,6))
plt.imshow(segmented_img)
plt.title("Segmented Image (KMeans)")
plt.show()
